# %% [markdown]
# # Minimum Viable Product

# %% [markdown]
# ## MTA Subway Traffic in Comparison to Temperatures During 2019

# %% [markdown]
# The main goal of this project is to see if there is a pattern in daily NYC subway traffic in regards to the temperatures of each day of 2019.

# %% [markdown]
# ![daily_entries_half_jan_2019.png](attachment:daily_entries_half_jan_2019.png)

# %% [markdown]
# ![daily_max_temps_half_jan_2019.png](attachment:daily_max_temps_half_jan_2019.png)
