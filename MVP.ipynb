# %% [markdown]
# # Minimum Viable Product

# %% [markdown]
# ## MTA Subway Traffic in Manhattan Throughout 2021

# %% [markdown]
# The main goal of this project is to find the top 5 subway stations in Manhattan with the highest foot traffic.

# %% [markdown]
# ![fig1.png](attachment:fig1.png)
